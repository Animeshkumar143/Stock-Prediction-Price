# %% [markdown]
# <a href="https://colab.research.google.com/github/Animeshkumar143/Stock-Prediction-Price/blob/main/Stock_Price_Predection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Loading Our Dataset**

# %%
from google.colab import files

# %%
dataset = files.upload()
# Out:
#      <input type="file" id="files-67f06db3-f5cf-4c68-88a0-8160558d29f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67f06db3-f5cf-4c68-88a0-8160558d29f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TSLA.csv to TSLA.csv

# %%
df = pd.read_csv('TSLA.csv')

# %% [markdown]
# ## **Feature Extraction**

# %% [markdown]
#  The number of the trading days and the columns:

# %%
df.shape
# Out:
# (2392, 7)

# %%
df = df['Open'].values
df = df.reshape(-1, 1)

# %% [markdown]
# After extracting one column:

# %%
df.shape
# Out:
# (2392, 1)

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8):])
print(dataset_train.shape)
print(dataset_test.shape)
# Out:
# (1913, 1)
# (479, 1)

# %% [markdown]
# Importing our model:

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout

# %% [markdown]
# Scaling data:

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_train[:5]
# Out:
# array([[0.0239104 ],
#        [0.01851302],
#        [0.01041695],
#        [0.00070166],
#        [0.        ]])

# %%
dataset_test = scaler.transform(dataset_test)
dataset_test[:5]
# Out:
# array([[0.8340845 ],
#        [0.87127243],
#        [0.88293085],
#        [0.81983541],
#        [0.80958041]])

# %%
def create_dataset(df):
    x = []
    y = []
    for i in range(50, df.shape[0]):
        x.append(df[i-50:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return x,y

# %% [markdown]
# Creating training and testing datasets:

# %%
x_train, y_train = create_dataset(dataset_train)
x_test, y_test = create_dataset(dataset_test)

# %% [markdown]
# Creating our LSTM model:

# %%
model = Sequential()
model.add(LSTM(units=96, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=96, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=96))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %% [markdown]
# Reshape features for the LSTM layer:

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# Start the training:

# %%
model.fit(x_train, y_train, epochs=50, batch_size=32)
model.save('stock_prediction.h5')
# Out:
# Epoch 1/50
# 59/59 [==============================] - 16s 142ms/step - loss: 0.0176
# Epoch 2/50
# 59/59 [==============================] - 9s 144ms/step - loss: 0.0040
# Epoch 3/50
# 59/59 [==============================] - 9s 155ms/step - loss: 0.0035
# Epoch 4/50
# 59/59 [==============================] - 8s 131ms/step - loss: 0.0029
# Epoch 5/50
# 59/59 [==============================] - 9s 152ms/step - loss: 0.0031
# Epoch 6/50
# 59/59 [==============================] - 9s 156ms/step - loss: 0.0027
# Epoch 7/50
# 59/59 [==============================] - 8s 131ms/step - loss: 0.0027
# Epoch 8/50
# 59/59 [==============================] - 10s 172ms/step - loss: 0.0025
# Epoch 9/50
# 59/59 [==============================] - 9s 155ms/step - loss: 0.0028
# Epoch 10/50
# 59/59 [==============================] - 8s 131ms/step - loss: 0.0023
# Epoch 11/50
# 59/59 [==============================] - 9s 156ms/step - loss: 0.0020
# Epoch 12/50
# ...

# %%
model = load_model('stock_prediction.h5')

# %% [markdown]
# ## **Results visualization**

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

fig, ax = plt.subplots(figsize=(16,8))
ax.set_facecolor('#000041')
ax.plot(y_test_scaled, color='red', label='Original price')
plt.plot(predictions, color='cyan', label='Predicted price')
plt.legend()
# Out:
# 14/14 [==============================] - 2s 43ms/step
